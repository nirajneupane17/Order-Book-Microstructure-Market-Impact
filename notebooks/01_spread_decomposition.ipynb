# %% [markdown]
# # 01 · Bid-Ask Spread Decomposition
# **Quant Trading Series — Project 4 of 20**
# Adverse selection · inventory · order processing costs.
# Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd, matplotlib.pyplot as plt
from microstructure import roll_spread, effective_spread, spread_decomposition
print("OK")

# %%
bars=pd.read_csv("../data/minute_bars.csv",parse_dates=["datetime"])
exe=pd.read_csv("../data/execution_analysis.csv")
print(exe[["stock","spread_cost_bps","vwap","twap"]].groupby("stock").mean().round(4).to_string())

# %%
img=plt.imread("../results/02_spread_analysis.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()

# %% [markdown]
# # 02 · Kyle's Lambda & Order Flow Imbalance
# **Quant Trading Series — Project 4 of 20**
# Price impact per unit order flow · OFI as alpha signal.
# Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from microstructure import kyle_lambda, order_flow_imbalance
print("OK")

# %%
bars=pd.read_csv("../data/minute_bars.csv",parse_dates=["datetime"])
exe=pd.read_csv("../data/execution_analysis.csv")
print("Kyle Lambda by stock (×10⁻⁶):")
print((exe.groupby("stock")["kyle_lambda"].mean().abs()*1e6).round(4))

# %%
img=plt.imread("../results/03_market_impact.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()

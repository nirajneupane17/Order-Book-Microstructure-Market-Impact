# %% [markdown]
# # 03 · Amihud Illiquidity Ratio
# **Quant Trading Series — Project 4 of 20**
# Return per dollar volume · liquidity risk · position sizing.
# Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd, matplotlib.pyplot as plt
from microstructure import amihud_illiquidity
print("OK")

# %%
daily=pd.read_csv("../data/daily_microstructure.csv")
print("Amihud Illiquidity (×10⁻⁶) — higher = less liquid:")
print((daily.groupby("stock")["amihud"].mean()*1e6).round(4))

# %%
img=plt.imread("../results/04_amihud_illiquidity.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()

# %% [markdown]
# # 04 · VWAP / TWAP Execution Benchmarks
# **Quant Trading Series — Project 4 of 20**
# Execution benchmarks · intraday scheduling · slippage analysis.
# Author: Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
import pandas as pd, matplotlib.pyplot as plt
from microstructure import vwap, twap
from tca_analytics import tca_report
print("OK")

# %%
exe=pd.read_csv("../data/execution_analysis.csv")
report=tca_report(exe)
print("TCA Report:")
print(report.to_string())

# %%
img=plt.imread("../results/05_vwap_twap.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()
